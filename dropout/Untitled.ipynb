# %%
df = pd.read_csv("archive2/student dropout.csv", encoding="ISO-8859-1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("archive2/student dropout.csv", encoding="ISO-8859-1")
#
# NameError: name 'pd' is not defined

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("archive2/student dropout.csv", encoding="ISO-8859-1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("archive2/student dropout.csv", encoding="ISO-8859-1")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv("archive2/student dropout.csv", encoding="ISO-8859-1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("archive2/student dropout.csv", encoding="ISO-8859-1")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("abdullah0a/student-dropout-analysis-and-prediction-dataset")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("abdullah0a/student-dropout-analysis-and-prediction-dataset")
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
# !pip install kagglehub
# Out:
# ...
#
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
# ...

# %%
os.environ["dishaaab"] = "your_kaggle_username"
os.environ["KGAT_bb3b27021ac6719f9d2fa827963dc580"]      = "your_new_api_key"

import kagglehub
import pandas as pd

path = kagglehub.dataset_download("abdullah0a/student-dropout-analysis-and-prediction-dataset")

csv_file = [f for f in os.listdir(path) if f.endswith('.csv')][0]
df = pd.read_csv(os.path.join(path, csv_file))
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 os.environ["dishaaab"] = "your_kaggle_username"
#       2 os.environ["KGAT_bb3b27021ac6719f9d2fa827963dc580"]      = "your_new_api_key"
#       4 import kagglehub
#
# NameError: name 'os' is not defined

# %%
import os

# %%
os.environ["dishaaab"] = "your_kaggle_username"
os.environ["KGAT_bb3b27021ac6719f9d2fa827963dc580"]      = "your_new_api_key"

# %%
import kagglehub
import pandas as pd

path = kagglehub.dataset_download("abdullah0a/student-dropout-analysis-and-prediction-dataset")

csv_file = [f for f in os.listdir(path) if f.endswith('.csv')][0]
df = pd.read_csv(os.path.join(path, csv_file))
df.head()
# Out:
# ...
# 100%|██████████| 11.3k/11.3k [00:00<00:00, 2.51MB/s]
# Extracting files...
#   School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0     GP      F   18       U         GT3               A                 4
# 1     GP      F   17       U         GT3               T                 1
# 2     GP      F   15       U         LE3               T                 1
# 3     GP      F   15       U         GT3               T                 4
# 4     GP      F   16       U         GT3               T                 3
#
#    Father_Education Mother_Job Father_Job  ... Free_Time Going_Out  \
# 0                 4    at_home    teacher  ...         3         4
# 1                 1    at_home      other  ...         3         3
# 2                 1    at_home      other  ...         3         2
# 3                 2     health   services  ...         2         2
# 4                 3      other      other  ...         3         2
#
# ...

# %%
print(df.shape)
print(df.columns.tolist())
print(df.dtypes)
df.head()
# Out:
# (649, 34)
# ['School', 'Gender', 'Age', 'Address', 'Family_Size', 'Parental_Status', 'Mother_Education', 'Father_Education', 'Mother_Job', 'Father_Job', 'Reason_for_Choosing_School', 'Guardian', 'Travel_Time', 'Study_Time', 'Number_of_Failures', 'School_Support', 'Family_Support', 'Extra_Paid_Class', 'Extra_Curricular_Activities', 'Attended_Nursery', 'Wants_Higher_Education', 'Internet_Access', 'In_Relationship', 'Family_Relationship', 'Free_Time', 'Going_Out', 'Weekend_Alcohol_Consumption', 'Weekday_Alcohol_Consumption', 'Health_Status', 'Number_of_Absences', 'Grade_1', 'Grade_2', 'Final_Grade', 'Dropped_Out']
# School                         object
# Gender                         object
# Age                             int64
# Address                        object
# Family_Size                    object
# Parental_Status                object
# Mother_Education                int64
# Father_Education                int64
# Mother_Job                     object
# ...

# %%
print(df['Dropped_Out'].value_counts())
# Out:
# Dropped_Out
# False    549
# True     100
# Name: count, dtype: int64

# %%
import numpy as np

# Numeric → median, Categorical → mode
for col in df.select_dtypes(include=[np.number]).columns:
    df[col] = df[col].fillna(df[col].median())

for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].fillna(df[col].mode()[0])

print("Missing values remaining:", df.isnull().sum().sum())
# Out:
# Missing values remaining: 0

# %%
from sklearn.preprocessing import LabelEncoder

encoders = {}
for col in df.select_dtypes(include=['object']).columns:
    if col != 'Dropout':
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))
        encoders[col] = le

print("Encoding done ✓")
# Out:
# Encoding done ✓

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns=['Dropped_Out'])
y = df['Dropped_Out']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)
print(f"Train: {X_train.shape[0]} rows | Test: {X_test.shape[0]} rows")
# Out:
# Train: 519 rows | Test: 130 rows

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

y_pred = model.predict(X_test_scaled)

print(f"Accuracy  : {accuracy_score(y_test, y_pred):.4f}")
print(f"Precision : {precision_score(y_test, y_pred):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred):.4f}")
print(f"F1 Score  : {f1_score(y_test, y_pred):.4f}")
print("\nFull Report:\n", classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
# ----> 3 y_pred = model.predict(X_test_scaled)
#       5 print(f"Accuracy  : {accuracy_score(y_test, y_pred):.4f}")
#       6 print(f"Precision : {precision_score(y_test, y_pred):.4f}")
#
# NameError: name 'model' is not defined

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled  = scaler.transform(X_test)

model = LogisticRegression(max_iter=1000, class_weight='balanced', random_state=42)
model.fit(X_train_scaled, y_train)
print("Model trained ✓")
# Out:
# Model trained ✓

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

y_pred = model.predict(X_test_scaled)

print(f"Accuracy  : {accuracy_score(y_test, y_pred):.4f}")
print(f"Precision : {precision_score(y_test, y_pred):.4f}")
print(f"Recall    : {recall_score(y_test, y_pred):.4f}")
print(f"F1 Score  : {f1_score(y_test, y_pred):.4f}")
print("\nFull Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy  : 0.9462
# Precision : 0.7826
# Recall    : 0.9000
# F1 Score  : 0.8372
#
# Full Report:
#                precision    recall  f1-score   support
#
#        False       0.98      0.95      0.97       110
#         True       0.78      0.90      0.84        20
#
#     accuracy                           0.95       130
#    macro avg       0.88      0.93      0.90       130
# weighted avg       0.95      0.95      0.95       130

# %%
import pickle, json

with open("dropout_model.pkl",    "wb") as f: pickle.dump(model,   f)
with open("scaler.pkl",           "wb") as f: pickle.dump(scaler,  f)
with open("label_encoders.pkl",   "wb") as f: pickle.dump(encoders,f)
with open("feature_columns.json", "w")  as f: json.dump(X_train.columns.tolist(), f)

print("All artifacts saved ✓")
print("Files: dropout_model.pkl | scaler.pkl | label_encoders.pkl | feature_columns.json")
# Out:
# All artifacts saved ✓
# Files: dropout_model.pkl | scaler.pkl | label_encoders.pkl | feature_columns.json

# %%
ARTIFACTS_DIR = os.path.join(os.path.dirname(os.path.abspath(__file__)), "..", "dropout")

PATHS = {
    "model":    os.path.join(ARTIFACTS_DIR, "dropout_model.pkl"),
    "scaler":   os.path.join(ARTIFACTS_DIR, "scaler.pkl"),
    "encoders": os.path.join(ARTIFACTS_DIR, "label_encoders.pkl"),
    "features": os.path.join(ARTIFACTS_DIR, "feature_columns.json"),
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 ARTIFACTS_DIR = os.path.join(os.path.dirname(os.path.abspath(__file__)), "..", "dropout")
#       3 PATHS = {
#       4     "model":    os.path.join(ARTIFACTS_DIR, "dropout_model.pkl"),
#       5     "scaler":   os.path.join(ARTIFACTS_DIR, "scaler.pkl"),
#       6     "encoders": os.path.join(ARTIFACTS_DIR, "label_encoders.pkl"),
#       7     "features": os.path.join(ARTIFACTS_DIR, "feature_columns.json"),
#       8 }
#
# NameError: name '__file__' is not defined

# %%
import json
with open("feature_columns.json", "r") as f:
    features = json.load(f)
print(features)
# Out:
# ['School', 'Gender', 'Age', 'Address', 'Family_Size', 'Parental_Status', 'Mother_Education', 'Father_Education', 'Mother_Job', 'Father_Job', 'Reason_for_Choosing_School', 'Guardian', 'Travel_Time', 'Study_Time', 'Number_of_Failures', 'School_Support', 'Family_Support', 'Extra_Paid_Class', 'Extra_Curricular_Activities', 'Attended_Nursery', 'Wants_Higher_Education', 'Internet_Access', 'In_Relationship', 'Family_Relationship', 'Free_Time', 'Going_Out', 'Weekend_Alcohol_Consumption', 'Weekday_Alcohol_Consumption', 'Health_Status', 'Number_of_Absences', 'Grade_1', 'Grade_2', 'Final_Grade']
